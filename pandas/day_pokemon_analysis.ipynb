# %%
import pandas as pd

df =pd.read_csv("pokemon.csv", index_col="name")

print (df)
# Out:
#              id   type_1  type_2   hp  attack  defense  sp_atk  sp_def  speed
# name
# Bulbasaur     1    Grass  Poison   45      49       49      65      65     45
# Ivysaur       2    Grass  Poison   60      62       63      80      80     60
# Venusaur      3    Grass  Poison   80      82       83     100     100     80
# Charmander    4     Fire     NaN   39      52       43      60      50     65
# Charmeleon    5     Fire     NaN   58      64       58      80      65     80
# ...         ...      ...     ...  ...     ...      ...     ...     ...    ...
# Dratini     147   Dragon     NaN   41      64       45      50      50     50
# Dragonair   148   Dragon     NaN   61      84       65      70      70     70
# Dragonite   149   Dragon  Flying   91     134       95     100     100     80
# Mewtwo      150  Psychic     NaN  106     110       90     154      90    130
# Mew         151  Psychic     NaN  100     100      100     100     100    100
#
# [151 rows x 9 columns]

# %%
print(df.head())
print(df.tail())
# Out:
#             id type_1  type_2  hp  attack  defense  sp_atk  sp_def  speed
# name
# Bulbasaur    1  Grass  Poison  45      49       49      65      65     45
# Ivysaur      2  Grass  Poison  60      62       63      80      80     60
# Venusaur     3  Grass  Poison  80      82       83     100     100     80
# Charmander   4   Fire     NaN  39      52       43      60      50     65
# Charmeleon   5   Fire     NaN  58      64       58      80      65     80
#             id   type_1  type_2   hp  attack  defense  sp_atk  sp_def  speed
# name
# Dratini    147   Dragon     NaN   41      64       45      50      50     50
# Dragonair  148   Dragon     NaN   61      84       65      70      70     70
# Dragonite  149   Dragon  Flying   91     134       95     100     100     80
# Mewtwo     150  Psychic     NaN  106     110       90     154      90    130
# Mew        151  Psychic     NaN  100     100      100     100     100    100

# %%
print(f"Rows: {df.shape[0]}")
print(f"Column: {df.shape[1]}")
print(df.columns.tolist())
print(df.dtypes)
print(df.info())
# Out:
# Rows: 151
# Column: 9
# ['id', 'type_1', 'type_2', 'hp', 'attack', 'defense', 'sp_atk', 'sp_def', 'speed']
# id          int64
# type_1     object
# type_2     object
# hp          int64
# attack      int64
# defense     int64
# sp_atk      int64
# sp_def      int64
# speed       int64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, Bulbasaur to Mew
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       151 non-null    int64
#  1   type_1   151 non-null    object
#  2   type_2   65 non-null     object
#  3   hp       151 non-null    int64
#  4   attack   151 non-null    int64
#  5   defense  151 non-null    int64
#  6   sp_atk   151 non-null    int64
#  7   sp_def   151 non-null    int64
#  8   speed    151 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 11.8+ KB
# None

# %%
print(df.isnull().to_string())
count_missing=df[df["type_2"].isnull()]
print(f"Pokemon with no type2 {count_missing}")
# Out:
#                id  type_1  type_2     hp  attack  defense  sp_atk  sp_def  speed
# name
# Bulbasaur   False   False   False  False   False    False   False   False  False
# Ivysaur     False   False   False  False   False    False   False   False  False
# Venusaur    False   False   False  False   False    False   False   False  False
# Charmander  False   False    True  False   False    False   False   False  False
# Charmeleon  False   False    True  False   False    False   False   False  False
# Charizard   False   False   False  False   False    False   False   False  False
# Squirtle    False   False    True  False   False    False   False   False  False
# Wartortle   False   False    True  False   False    False   False   False  False
# Blastoise   False   False    True  False   False    False   False   False  False
# Caterpie    False   False    True  False   False    False   False   False  False
# Metapod     False   False    True  False   False    False   False   False  False
# Butterfree  False   False   False  False   False    False   False   False  False
# Weedle      False   False   False  False   False    False   False   False  False
# Kakuna      False   False   False  False   False    False   False   False  False
# Beedrill    False   False   False  False   False    False   False   False  False
# Pidgey      False   False   False  False   False    False   False   False  False
# Pidgeotto   False   False   False  False   False    False   False   False  False
# Pidgeot     False   False   False  False   False    False   False   False  False
# Rattata     False   False    True  False   False    False   False   False  False
# Raticate    False   False    True  False   False    False   False   False  False
# Spearow     False   False   False  False   False    False   False   False  False
# Fearow      False   False   False  False   False    False   False   False  False
# Ekans       False   False    True  False   False    False   False   False  False
# Arbok       False   False    True  False   False    False   False   False  False
# Pikachu     False   False    True  False   False    False   False   False  False
# Raichu      False   False    True  False   False    False   False   False  False
# Sandshrew   False   False    True  False   False    False   False   False  False
# Sandslash   False   False    True  False   False    False   False   False  False
# Nidoran♀    False   False    True  False   False    False   False   False  False
# Nidorina    False   False    True  False   False    False   False   False  False
# Nidoqueen   False   False   False  False   False    False   False   False  False
# Nidoran♂    False   False    True  False   False    False   False   False  False
# Nidorino    False   False    True  False   False    False   False   False  False
# Nidoking    False   False   False  False   False    False   False   False  False
# Clefairy    False   False    True  False   False    False   False   False  False
# Clefable    False   False    True  False   False    False   False   False  False
# Vulpix      False   False    True  False   False    False   False   False  False
# Ninetales   False   False    True  False   False    False   False   False  False
# Jigglypuff  False   False    True  False   False    False   False   False  False
# Wigglytuff  False   False    True  False   False    False   False   False  False
# Zubat       False   False   False  False   False    False   False   False  False
# Golbat      False   False   False  False   False    False   False   False  False
# Oddish      False   False   False  False   False    False   False   False  False
# Gloom       False   False   False  False   False    False   False   False  False
# Vileplume   False   False   False  False   False    False   False   False  False
# Paras       False   False   False  False   False    False   False   False  False
# Parasect    False   False   False  False   False    False   False   False  False
# Venonat     False   False   False  False   False    False   False   False  False
# Venomoth    False   False   False  False   False    False   False   False  False
# Diglett     False   False    True  False   False    False   False   False  False
# Dugtrio     False   False    True  False   False    False   False   False  False
# Meowth      False   False    True  False   False    False   False   False  False
# Persian     False   False    True  False   False    False   False   False  False
# Psyduck     False   False    True  False   False    False   False   False  False
# Golduck     False   False    True  False   False    False   False   False  False
# Mankey      False   False    True  False   False    False   False   False  False
# Primeape    False   False    True  False   False    False   False   False  False
# Growlithe   False   False    True  False   False    False   False   False  False
# Arcanine    False   False    True  False   False    False   False   False  False
# Poliwag     False   False    True  False   False    False   False   False  False
# Poliwhirl   False   False    True  False   False    False   False   False  False
# Poliwrath   False   False   False  False   False    False   False   False  False
# Abra        False   False    True  False   False    False   False   False  False
# Kadabra     False   False    True  False   False    False   False   False  False
# Alakazam    False   False    True  False   False    False   False   False  False
# Machop      False   False    True  False   False    False   False   False  False
# Machoke     False   False    True  False   False    False   False   False  False
# Machamp     False   False    True  False   False    False   False   False  False
# Bellsprout  False   False   False  False   False    False   False   False  False
# Weepinbell  False   False   False  False   False    False   False   False  False
# Victreebel  False   False   False  False   False    False   False   False  False
# Tentacool   False   False   False  False   False    False   False   False  False
# Tentacruel  False   False   False  False   False    False   False   False  False
# Geodude     False   False   False  False   False    False   False   False  False
# Graveler    False   False   False  False   False    False   False   False  False
# Golem       False   False   False  False   False    False   False   False  False
# Ponyta      False   False    True  False   False    False   False   False  False
# Rapidash    False   False    True  False   False    False   False   False  False
# Slowpoke    False   False   False  False   False    False   False   False  False
# Slowbro     False   False   False  False   False    False   False   False  False
# Magnemite   False   False   False  False   False    False   False   False  False
# Magneton    False   False   False  False   False    False   False   False  False
# Farfetch'd  False   False   False  False   False    False   False   False  False
# Doduo       False   False   False  False   False    False   False   False  False
# Dodrio      False   False   False  False   False    False   False   False  False
# Seel        False   False    True  False   False    False   False   False  False
# Dewgong     False   False   False  False   False    False   False   False  False
# Grimer      False   False    True  False   False    False   False   False  False
# Muk         False   False    True  False   False    False   False   False  False
# Shellder    False   False    True  False   False    False   False   False  False
# Cloyster    False   False   False  False   False    False   False   False  False
# Gastly      False   False   False  False   False    False   False   False  False
# Haunter     False   False   False  False   False    False   False   False  False
# Gengar      False   False   False  False   False    False   False   False  False
# Onix        False   False   False  False   False    False   False   False  False
# Drowzee     False   False    True  False   False    False   False   False  False
# Hypno       False   False    True  False   False    False   False   False  False
# Krabby      False   False    True  False   False    False   False   False  False
# Kingler     False   False    True  False   False    False   False   False  False
# Voltorb     False   False    True  False   False    False   False   False  False
# Electrode   False   False    True  False   False    False   False   False  False
# Exeggcute   False   False   False  False   False    False   False   False  False
# Exeggutor   False   False   False  False   False    False   False   False  False
# Cubone      False   False    True  False   False    False   False   False  False
# Marowak     False   False    True  False   False    False   False   False  False
# Hitmonlee   False   False    True  False   False    False   False   False  False
# Hitmonchan  False   False    True  False   False    False   False   False  False
# Lickitung   False   False    True  False   False    False   False   False  False
# Koffing     False   False    True  False   False    False   False   False  False
# Weezing     False   False    True  False   False    False   False   False  False
# Rhyhorn     False   False   False  False   False    False   False   False  False
# Rhydon      False   False   False  False   False    False   False   False  False
# Chansey     False   False    True  False   False    False   False   False  False
# Tangela     False   False    True  False   False    False   False   False  False
# Kangaskhan  False   False    True  False   False    False   False   False  False
# Horsea      False   False    True  False   False    False   False   False  False
# Seadra      False   False    True  False   False    False   False   False  False
# Goldeen     False   False    True  False   False    False   False   False  False
# Seaking     False   False    True  False   False    False   False   False  False
# Staryu      False   False    True  False   False    False   False   False  False
# Starmie     False   False   False  False   False    False   False   False  False
# Mr. Mime    False   False   False  False   False    False   False   False  False
# Scyther     False   False   False  False   False    False   False   False  False
# Jynx        False   False   False  False   False    False   False   False  False
# Electabuzz  False   False    True  False   False    False   False   False  False
# Magmar      False   False    True  False   False    False   False   False  False
# Pinsir      False   False    True  False   False    False   False   False  False
# Tauros      False   False    True  False   False    False   False   False  False
# Magikarp    False   False    True  False   False    False   False   False  False
# Gyarados    False   False   False  False   False    False   False   False  False
# Lapras      False   False   False  False   False    False   False   False  False
# Ditto       False   False    True  False   False    False   False   False  False
# Eevee       False   False    True  False   False    False   False   False  False
# Vaporeon    False   False    True  False   False    False   False   False  False
# Jolteon     False   False    True  False   False    False   False   False  False
# Flareon     False   False    True  False   False    False   False   False  False
# Porygon     False   False    True  False   False    False   False   False  False
# Omanyte     False   False   False  False   False    False   False   False  False
# Omastar     False   False   False  False   False    False   False   False  False
# Kabuto      False   False   False  False   False    False   False   False  False
# Kabutops    False   False   False  False   False    False   False   False  False
# Aerodactyl  False   False   False  False   False    False   False   False  False
# Snorlax     False   False    True  False   False    False   False   False  False
# Articuno    False   False   False  False   False    False   False   False  False
# Zapdos      False   False   False  False   False    False   False   False  False
# Moltres     False   False   False  False   False    False   False   False  False
# Dratini     False   False    True  False   False    False   False   False  False
# Dragonair   False   False    True  False   False    False   False   False  False
# Dragonite   False   False   False  False   False    False   False   False  False
# Mewtwo      False   False    True  False   False    False   False   False  False
# Mew         False   False    True  False   False    False   False   False  False
# Pokemon with no type2              id   type_1 type_2   hp  attack  defense  sp_atk  sp_def  speed
# name
# Charmander    4     Fire    NaN   39      52       43      60      50     65
# Charmeleon    5     Fire    NaN   58      64       58      80      65     80
# Squirtle      7    Water    NaN   44      48       65      50      64     43
# Wartortle     8    Water    NaN   59      63       80      65      80     58
# Blastoise     9    Water    NaN   79      83      100      85     105     78
# ...         ...      ...    ...  ...     ...      ...     ...     ...    ...
# Snorlax     143   Normal    NaN  160     110       65      65     110     30
# Dratini     147   Dragon    NaN   41      64       45      50      50     50
# Dragonair   148   Dragon    NaN   61      84       65      70      70     70
# Mewtwo      150  Psychic    NaN  106     110       90     154      90    130
# Mew         151  Psychic    NaN  100     100      100     100     100    100
#
# [86 rows x 9 columns]

# %%
fire_type=df[df["type_1"]=="Fire"]
print(fire_type)
attcking_pokemon=df[df["attack"]>100]
print(attcking_pokemon)
df['total']=df['attack']+df['defense']+df['speed']+df["sp_atk"]+df['sp_def']
print(df.head())
high_stat=(df[df['total']>300])
print(high_stat)
# Out:
#              id type_1  type_2  hp  attack  defense  sp_atk  sp_def  speed
# name
# Charmander    4   Fire     NaN  39      52       43      60      50     65
# Charmeleon    5   Fire     NaN  58      64       58      80      65     80
# Charizard     6   Fire  Flying  78      84       78     109      85    100
# Vulpix       37   Fire     NaN  38      41       40      50      65     65
# Ninetales    38   Fire     NaN  73      76       75      81     100    100
# Growlithe    58   Fire     NaN  55      70       45      70      50     60
# Arcanine     59   Fire     NaN  90     110       80     100      80     95
# Ponyta       77   Fire     NaN  50      85       55      65      65     90
# Rapidash     78   Fire     NaN  65     100       70      80      80    105
# Magmar      126   Fire     NaN  65      95       57     100      85     93
# Flareon     136   Fire     NaN  65     130       60      95     110     65
# Moltres     146   Fire  Flying  90     100       90     125      85     90
#              id    type_1  type_2   hp  attack  defense  sp_atk  sp_def  speed
# name
# Nidoking     34    Poison  Ground   81     102       77      85      75     85
# Primeape     57  Fighting     NaN   65     105       60      60      70     95
# Arcanine     59      Fire     NaN   90     110       80     100      80     95
# Machamp      68  Fighting     NaN   90     130       80      65      85     55
# Victreebel   71     Grass  Poison   80     105       65     100      70     70
# Golem        76      Rock  Ground   80     120      130      55      65     45
# Dodrio       85    Normal  Flying   60     110       70      60      60    110
# Muk          89    Poison     NaN  105     105       75      65     100     50
# Krabby       98     Water     NaN   30     105       90      25      25     50
# Kingler      99     Water     NaN   55     130      115      50      50     75
# Hitmonlee   106  Fighting     NaN   50     120       53      35     110     87
# Hitmonchan  107  Fighting     NaN   50     105       79      35     110     76
# Rhydon      112    Ground    Rock  105     130      120      45      45     40
# Scyther     123       Bug  Flying   70     110       80      55      80    105
# Pinsir      127       Bug     NaN   65     125      100      55      70     85
# Gyarados    130     Water  Flying   95     125       79      60     100     81
# Flareon     136      Fire     NaN   65     130       60      95     110     65
# Kabutops    141      Rock   Water   60     115      105      65      70     80
# Aerodactyl  142      Rock  Flying   80     105       65      60      75    130
# Snorlax     143    Normal     NaN  160     110       65      65     110     30
# Dragonite   149    Dragon  Flying   91     134       95     100     100     80
# Mewtwo      150   Psychic     NaN  106     110       90     154      90    130
#             id type_1  type_2  hp  attack  defense  sp_atk  sp_def  speed  \
# name
# Bulbasaur    1  Grass  Poison  45      49       49      65      65     45
# Ivysaur      2  Grass  Poison  60      62       63      80      80     60
# Venusaur     3  Grass  Poison  80      82       83     100     100     80
# Charmander   4   Fire     NaN  39      52       43      60      50     65
# Charmeleon   5   Fire     NaN  58      64       58      80      65     80
#
#             total
# name
# Bulbasaur     273
# Ivysaur       345
# Venusaur      445
# Charmander    270
# Charmeleon    347
#              id   type_1  type_2   hp  attack  defense  sp_atk  sp_def  speed  \
# name
# Ivysaur       2    Grass  Poison   60      62       63      80      80     60
# Venusaur      3    Grass  Poison   80      82       83     100     100     80
# Charmeleon    5     Fire     NaN   58      64       58      80      65     80
# Charizard     6     Fire  Flying   78      84       78     109      85    100
# Wartortle     8    Water     NaN   59      63       80      65      80     58
# ...         ...      ...     ...  ...     ...      ...     ...     ...    ...
# Moltres     146     Fire  Flying   90     100       90     125      85     90
# Dragonair   148   Dragon     NaN   61      84       65      70      70     70
# Dragonite   149   Dragon  Flying   91     134       95     100     100     80
# Mewtwo      150  Psychic     NaN  106     110       90     154      90    130
# Mew         151  Psychic     NaN  100     100      100     100     100    100
#
#             total
# name
# Ivysaur       345
# Venusaur      445
# Charmeleon    347
# Charizard     456
# Wartortle     346
# ...           ...
# Moltres       490
# Dragonair     359
# Dragonite     509
# Mewtwo        574
# Mew           500
#
# [92 rows x 10 columns]

# %%
print((df["hp"].mean()))
print((df["attack"].mean()))
print((df["defense"].mean()))

highest_attack_row = df[df['attack'] == df['attack'].max()]

print(highest_attack_row)

slowest_pokemon=df[df['speed']==df['speed'].min()]
print(slowest_pokemon)

type_counter=df['type_1'].value_counts()
print(type_counter)
# Out:
#           id type_1   type_2  hp  attack  defense  sp_atk  sp_def  speed
# name
# Slowpoke  79  Water  Psychic  90      65       65      40      40     15
# type_1
# Water       28
# Normal      24
# Poison      14
# Grass       12
# Fire        12
# Bug         12
# Electric     9
# Rock         9
# Psychic      8
# Ground       8
# Fighting     7
# Ghost        3
# Dragon       3
# Ice          2
# Name: count, dtype: int64

# %%
group=df.groupby("type_1")
print(group["attack"].mean())
print(group["defense"].mean())
print(group["speed"].mean())

avg_speed = df.groupby('type_1')['speed'].mean()
highest_type = avg_speed.idxmax()
highest_value = avg_speed.max()
print(f"The Type 1 with the highest average Speed is {highest_type} with {highest_value:.2f}")
print(avg_speed.sort_values(ascending=False))
# Out:
# The Type 1 with the highest average Speed is Electric with 100.00
# type_1
# Electric    100.000000
# Ghost        95.000000
# Psychic      93.000000
# Ice          90.000000
# Fire         84.000000
# Normal       67.916667
# Water        67.714286
# Dragon       66.666667
# Fighting     66.142857
# Poison       58.785714
# Rock         58.333333
# Ground       58.125000
# Bug          57.083333
# Grass        52.083333
# Name: speed, dtype: float64

# %%
df['Total'] = df['hp'] + df['attack'] + df['defense'] + df['sp_atk'] + df['sp_def'] + df['speed']
print(df["Total"])
comparison = df.groupby('type_1').agg({
    'Total': 'mean',
    'name': 'count',    
    'speed': 'max'      
})
comparison.columns = ['Avg Total', 'Pokemon Count', 'Max Speed']
print(comparison.head())
# Out:
# name
# Bulbasaur     318
# Ivysaur       405
# Venusaur      525
# Charmander    309
# Charmeleon    405
#              ...
# Dratini       300
# Dragonair     420
# Dragonite     600
# Mewtwo        680
# Mew           600
# Name: Total, Length: 151, dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 3
#       1 df['Total'] = df['hp'] + df['attack'] + df['defense'] + df['sp_atk'] + df['sp_def'] + df['speed']
#       2 print(df["Total"])
# ----> 3 comparison = df.groupby('type_1').agg({
#       4     'Total': 'mean',
#       5     'name': 'count',
#       6     'speed': 'max'
#       7 })
#       8 comparison.columns = ['Avg Total', 'Pokemon Count', 'Max Speed']
#       9 print(comparison.head())
#
# File c:\Users\SAYAN\Desktop\Ai_basic_python\.venv\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File c:\Users\SAYAN\Desktop\Ai_basic_python\.venv\Lib\site-packages\pandas\core\apply.py:190, in Apply.agg(self)
#     187     return self.apply_str()
#     189 if is_dict_like(func):
# --> 190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
#     193     return self.agg_list_like()
#
# File c:\Users\SAYAN\Desktop\Ai_basic_python\.venv\Lib\site-packages\pandas\core\apply.py:423, in Apply.agg_dict_like(self)
#     415 def agg_dict_like(self) -> DataFrame | Series:
#     416     """
#     417     Compute aggregation in the case of a dict-like argument.
#     418
#    (...)    421     Result of aggregation.
#     422     """
# --> 423     return self.agg_or_apply_dict_like(op_name="agg")
#
# File c:\Users\SAYAN\Desktop\Ai_basic_python\.venv\Lib\site-packages\pandas\core\apply.py:1603, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1598     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1600 with com.temp_setattr(
#    1601     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1602 ):
# -> 1603     result_index, result_data = self.compute_dict_like(
#    1604         op_name, selected_obj, selection, kwargs
#    1605     )
#    1606 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1607 return result
#
# File c:\Users\SAYAN\Desktop\Ai_basic_python\.venv\Lib\site-packages\pandas\core\apply.py:462, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     460 is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#     461 func = cast(AggFuncTypeDict, self.func)
# --> 462 func = self.normalize_dictlike_arg(op_name, selected_obj, func)
#     464 is_non_unique_col = (
#     465     selected_obj.ndim == 2
#     466     and selected_obj.columns.nunique() < len(selected_obj.columns)
#     467 )
#     469 if selected_obj.ndim == 1:
#     470     # key only used for output
#
# File c:\Users\SAYAN\Desktop\Ai_basic_python\.venv\Lib\site-packages\pandas\core\apply.py:663, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     661     cols = Index(list(func.keys())).difference(obj.columns, sort=True)
#     662     if len(cols) > 0:
# --> 663         raise KeyError(f"Column(s) {list(cols)} do not exist")
#     665 aggregator_types = (list, tuple, dict)
#     667 # if we have a dict of any non-scalars
#     668 # eg. {'A' : ['mean']}, normalize all to
#     669 # be list-likes
#     670 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['name'] do not exist"
