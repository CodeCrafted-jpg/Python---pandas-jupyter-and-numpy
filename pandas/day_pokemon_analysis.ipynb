# %%
import pandas as pd

df =pd.read_csv("pokemon.csv")

print (df)

# %%
print(df.head())
print(df.tail())

# %%
print(f"Rows: {df.shape[0]}")
print(f"Column: {df.shape[1]}")
print(df.columns.tolist())
print(df.dtypes)
print(df.info())
